# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# import dependencies
import pandas as pd
import numpy as np

# %%
# Read csv
geo_cuisine = pd.read_csv('GEOCUISINE.csv')

# Convert csv to data frame
geo_cuisine = pd.DataFrame(geo_cuisine)

geo_cuisine.head(130)
# Out:
#      placeid   latitude   longitude  \
# 0     135109  18.921785  -99.235350
# 1     135106  22.149709 -100.976093
# 2     135104  23.752982  -99.168434
# 3     135088  18.876011  -99.219890
# 4     135086  22.141421 -101.013955
# ..       ...        ...         ...
# 107   132594  23.752168  -99.165709
# 108   132584  23.752365  -99.165288
# 109   132583  18.922290  -99.234332
# 110   132572  22.141647 -100.992712
# 111   132560  23.752304  -99.166913
#
#                                         the_geom_meter  \
# 0    0101000020957F0000A6BF695F136F5AC1DADF87B20556...
# 1    0101000020957F0000649D6F21634858C119AE9BF528A3...
# 2    0101000020957F00007CDF5EAFC58157C1645743B23E4F...
# 3    0101000020957F0000E14AD4DBC7765AC1F7B33C85B153...
# 4    0101000020957F0000FA1A0E5A9B4858C17C884C4173AE...
# ..                                                 ...
# 107  0101000020957F00003AE4C6DBF48157C1CE38ECC1864E...
# 108  0101000020957F000048C65BA7EF8157C177F2344D664E...
# 109  0101000020957F0000FBE7171F056F5AC1E8A6C0A5AF55...
# 110  0101000020957F00005D19BF45294958C18FF7F8E260A8...
# 111  0101000020957F0000FC60BDA8E88157C1B2C357D6DA4E...
#
#                                    name                              address  \
# 0                             Paniroles                                    ?
# 1            El Rinc�n de San Francisco                      Universidad 169
# 2                                  vips                                    ?
# 3                     Cafeteria cenidet        Interior Internado Palmira SN
# 4           Mcdonalds Parque Tangamanga  Lateral Salvador Nava Martinez 3145
# ..                                  ...                                  ...
# 107  tacos de barbacoa enfrente del Tec                                    ?
# 108                  Gorditas Dona Tota                                    ?
# 109                    McDonalds Centro                 Rayon sn col. Centro
# 110                        Cafe Chaires                                    ?
# 111                  puesto de gorditas                frente al tecnologico
#
#                 city            state country fax  ...   smoking_area  \
# 0                  ?                ?       ?   ?  ...  not permitted
# 1    San Luis Potosi  San Luis Potosi  Mexico   ?  ...    only at bar
# 2                  ?                ?       ?   ?  ...  not permitted
# 3         Cuernavaca          Morelos  Mexico   ?  ...  not permitted
# 4    San Luis Potosi              SLP  Mexico   ?  ...  not permitted
# ..               ...              ...     ...  ..  ...            ...
# 107                ?                ?       ?   ?  ...  not permitted
# 108                ?                ?       ?   ?  ...  not permitted
# 109       Cuernavaca          Morelos  Mexico   ?  ...  not permitted
# 110  San Luis Potosi  San Luis Potosi  Mexico   ?  ...  not permitted
# 111         victoria       tamaulipas  mexico   ?  ...      permitted
#
#     dress_code     accessibility   price                 url rambience  \
# 0     informal  no_accessibility  medium                   ?     quiet
# 1     informal         partially  medium                   ?  familiar
# 2     informal        completely  medium                   ?  familiar
# 3     informal  no_accessibility     low  www.cenidet.edu.mx     quiet
# 4     informal  no_accessibility  medium                   ?  familiar
# ..         ...               ...     ...                 ...       ...
# 107   informal        completely     low                   ?  familiar
# 108   informal        completely  medium                   ?  familiar
# 109   informal         partially     low                  no  familiar
# 110   informal        completely     low                   ?  familiar
# 111   informal  no_accessibility     low                   ?  familiar
#
#     franchise    area other_services   rcuisine
# 0           f  closed       Internet    Italian
# 1           f    open           none    Mexican
# 2           t  closed        variety    Mexican
# 3           f  closed           none  Cafeteria
# 4           t  closed           none    Burgers
# ..        ...     ...            ...        ...
# 107         f    open           none    Mexican
# 108         t  closed           none    Mexican
# 109         t  closed           none   American
# 110         f  closed           none  Cafeteria
# 111         f    open           none   Regional
#
# [112 rows x 22 columns]

# %%
geo_cuisine.loc[geo_cuisine['address'] == '?']
# Out:
#      placeid   latitude   longitude  \
# 0     135109  18.921785  -99.235350
# 2     135104  23.752982  -99.168434
# 55    134976  18.916654  -99.227110
# 56    134976  18.916654  -99.227110
# 57    134976  18.916654  -99.227110
# 63    132925  22.153500 -100.976243
# 64    132922  22.151135 -100.982312
# 65    132921  22.150305 -100.989134
# 67    132875  22.149901 -100.993779
# 68    132872  22.173596 -100.994603
# 78    132851  22.136872 -100.934574
# 79    132851  22.136872 -100.934574
# 91    132740  23.752197  -99.166632
# 92    132733  23.752707  -99.162566
# 94    132723  22.148934 -101.019845
# 95    132717  23.731860  -99.150437
# 96    132715  23.732423  -99.158660
# 98    132668  23.738212  -99.151955
# 100   132665  23.736798  -99.134241
# 101   132663  23.752511  -99.166954
# 103   132626  23.737583  -99.135132
# 107   132594  23.752168  -99.165709
# 108   132584  23.752365  -99.165288
# 110   132572  22.141647 -100.992712
#
#                                         the_geom_meter  \
# 0    0101000020957F0000A6BF695F136F5AC1DADF87B20556...
# 2    0101000020957F00007CDF5EAFC58157C1645743B23E4F...
# 55   0101000020957F00002838E29F19705AC1BC368BDAC753...
# 56   0101000020957F00002838E29F19705AC1BC368BDAC753...
# 57   0101000020957F00002838E29F19705AC1BC368BDAC753...
# 63   0101000020957F00001EF62687CD4758C1BE336F4EFAA2...
# 64   0101000020957F000060A98A38FF4758C146718E41D9A4...
# 65   0101000020957F00006376BB64EF4758C1013687E5D7A6...
# 67   0101000020957F00008A2A0747DE4758C11EB31D2A31A8...
# 68   0101000020957F0000942C3434384458C1C2D3499804A7...
# 78   0101000020957F0000C74DE39C7F4B58C1061F29171498...
# 79   0101000020957F0000C74DE39C7F4B58C1061F29171498...
# 91   0101000020957F000027A30471EE8157C1AC17D61EC84E...
# 92   0101000020957F0000F2F4110CF28157C1DCFD7C1BA04D...
# 94   0101000020957F0000B366C9254B4758C191987F9CAEAF...
# 95   0101000020957F0000B21C3F6C5E8557C188ACCF0A444B...
# 96   0101000020957F00004609B96F198557C11973490A874D...
# 98   0101000020957F000003B195E25F8457C1C535BD04614B...
# 100  0101000020957F00007AED0830FC8457C122F85F7B8446...
# 101  0101000020957F0000FDF8D26EE08157C1FEDB6A1FDB4E...
# 103  0101000020957F0000AA7883ADD88457C1FA651328BA46...
# 107  0101000020957F00003AE4C6DBF48157C1CE38ECC1864E...
# 108  0101000020957F000048C65BA7EF8157C177F2344D664E...
# 110  0101000020957F00005D19BF45294958C18FF7F8E260A8...
#
#                                    name address             city  \
# 0                             Paniroles       ?                ?
# 2                                  vips       ?                ?
# 55                              Log Yin       ?                ?
# 56                              Log Yin       ?                ?
# 57                              Log Yin       ?                ?
# 63                          el pueblito       ?                ?
# 64                 cafe punta del cielo       ?                ?
# 65                             crudalia       ?                ?
# 67                            shi ro ie       ?                ?
# 68                      Pizzeria Julios       ?            s.l.p
# 78                                  KFC       ?  San Luis Potosi
# 79                                  KFC       ?  San Luis Potosi
# 91        Carreton de Flautas y Migadas       ?  Ciudad Victoria
# 92                        Little Cesarz       ?  Ciudad Victoria
# 94                    Gordas de morales       ?                ?
# 95                         tortas hawai       ?                ?
# 96                 tacos de la estacion       ?                ?
# 98                       TACOS EL GUERO       ?         victoria
# 100                  TACOS CORRECAMINOS       ?         victoria
# 101                           tacos abi       ?         victoria
# 103               la perica hamburguesa       ?         victoria
# 107  tacos de barbacoa enfrente del Tec       ?                ?
# 108                  Gorditas Dona Tota       ?                ?
# 110                        Cafe Chaires       ?  San Luis Potosi
#
#                state country fax  ...   smoking_area dress_code  \
# 0                  ?       ?   ?  ...  not permitted   informal
# 2                  ?       ?   ?  ...  not permitted   informal
# 55                 ?       ?   ?  ...           none   informal
# 56                 ?       ?   ?  ...           none   informal
# 57                 ?       ?   ?  ...           none   informal
# 63                 ?       ?   ?  ...  not permitted   informal
# 64                 ?       ?   ?  ...      permitted     formal
# 65                 ?       ?   ?  ...        section     casual
# 67                 ?       ?   ?  ...        section   informal
# 68            mexico       ?   ?  ...  not permitted   informal
# 78   San Luis Potosi  Mexico   ?  ...  not permitted   informal
# 79   San Luis Potosi  Mexico   ?  ...  not permitted   informal
# 91        Tamaulipas  Mexico   ?  ...      permitted   informal
# 92        Tamaulipas  Mexico   ?  ...  not permitted   informal
# 94   San Luis Potosi  Mexico   ?  ...        section   informal
# 95                 ?       ?   ?  ...  not permitted   informal
# 96                 ?       ?   ?  ...           none   informal
# 98        tamaulipas  mexico   ?  ...           none   informal
# 100       tamaulipas  mexico   ?  ...           none   informal
# 101       tamaulipas  mexico   ?  ...           none   informal
# 103       tamaulipas       ?   ?  ...           none   informal
# 107                ?       ?   ?  ...  not permitted   informal
# 108                ?       ?   ?  ...  not permitted   informal
# 110  San Luis Potosi  Mexico   ?  ...  not permitted   informal
#
#         accessibility   price url rambience franchise    area other_services  \
# 0    no_accessibility  medium   ?     quiet         f  closed       Internet
# 2          completely  medium   ?  familiar         t  closed        variety
# 55   no_accessibility     low   ?  familiar         f  closed           none
# 56   no_accessibility     low   ?  familiar         f  closed           none
# 57   no_accessibility     low   ?  familiar         f  closed           none
# 63         completely  medium   ?  familiar         f  closed           none
# 64         completely  medium   ?  familiar         f  closed           none
# 65         completely     low   ?     quiet         f    open           none
# 67   no_accessibility    high   ?  familiar         t    open       Internet
# 68          partially  medium   ?  familiar         f  closed           none
# 78         completely     low   ?  familiar         f  closed           none
# 79         completely     low   ?  familiar         f  closed           none
# 91         completely     low   ?  familiar         f    open           none
# 92         completely  medium   ?  familiar         t  closed           none
# 94         completely  medium   ?  familiar         f  closed           none
# 95          partially  medium   ?  familiar         f  closed           none
# 96   no_accessibility     low   ?     quiet         f    open           none
# 98         completely     low   ?  familiar         f  closed           none
# 100        completely     low   ?  familiar         f  closed           none
# 101        completely     low   ?  familiar         f  closed           none
# 103        completely  medium   ?  familiar         t  closed           none
# 107        completely     low   ?  familiar         f    open           none
# 108        completely  medium   ?  familiar         t  closed           none
# 110        completely     low   ?  familiar         f  closed           none
#
#           rcuisine
# 0          Italian
# 2          Mexican
# 55         Mexican
# 56   Mediterranean
# 57         Burgers
# 63         Mexican
# 64       Cafeteria
# 65             Bar
# 67        Japanese
# 68        American
# 78        American
# 79            Game
# 91         Mexican
# 92        Pizzeria
# 94         Mexican
# 95       Fast_Food
# 96         Mexican
# 98         Mexican
# 100        Mexican
# 101        Mexican
# 103        Italian
# 107        Mexican
# 108        Mexican
# 110      Cafeteria
#
# [24 rows x 22 columns]

# %%
geo_cuisine.columns
# Out:
# Index(['placeid', 'latitude', 'longitude', 'the_geom_meter', 'name', 'address',
#        'city', 'state', 'country', 'fax', 'zip', 'alcohol', 'smoking_area',
#        'dress_code', 'accessibility', 'price', 'url', 'rambience', 'franchise',
#        'area', 'other_services', 'rcuisine'],
#       dtype='object')

# %%
geo_cuisine = geo_cuisine.drop(columns={'fax','url','the_geom_meter','country','franchise','other_services','address','city','state', 'zip'})

# %%
geo_cuisine.head()
# Out:
#    placeid   latitude   longitude                         name  \
# 0   135109  18.921785  -99.235350                    Paniroles
# 1   135106  22.149709 -100.976093   El Rinc�n de San Francisco
# 2   135104  23.752982  -99.168434                         vips
# 3   135088  18.876011  -99.219890            Cafeteria cenidet
# 4   135086  22.141421 -101.013955  Mcdonalds Parque Tangamanga
#
#              alcohol   smoking_area dress_code     accessibility   price  \
# 0          Wine-Beer  not permitted   informal  no_accessibility  medium
# 1          Wine-Beer    only at bar   informal         partially  medium
# 2           Full_Bar  not permitted   informal        completely  medium
# 3  No_Alcohol_Served  not permitted   informal  no_accessibility     low
# 4  No_Alcohol_Served  not permitted   informal  no_accessibility  medium
#
#   rambience    area   rcuisine
# 0     quiet  closed    Italian
# 1  familiar    open    Mexican
# 2  familiar  closed    Mexican
# 3     quiet  closed  Cafeteria
# 4  familiar  closed    Burgers

# %%
geo_cuisine = geo_cuisine.rename(columns={'placeid':'Place ID',
                                        'longitude':'Longitude',
                                        'latitude':'Latitude',
                                        'name':'Name',
                                       'alcohol':'Alcohol',
                                       'smoking_area':'Smoking',
                                       'dress_code':'Dress Code',
                                       'accessibility':'Accessibility',
                                       'price':'Price',
                                       'rambience':'Ambience',
                                       'area':'Area',
                                       'rcuisine':'Cuisine'})

# %%
geo_cuisine.columns
# Out:
# Index(['Place ID', 'Latitude', 'Longitude', 'Name', 'Alcohol', 'Smoking',
#        'Dress Code', 'Accessibility', 'Price', 'Ambience', 'Area', 'Cuisine'],
#       dtype='object')

# %%
# geo_cuisine = geo_cuisine.loc[geo_cuisine['Place ID', 'Latitude', 'Longitude', 'Name', 'Alcohol', 'Smoking',
#        'Dress Code', 'Accessibility', 'Price', 'Ambience', 'Area', 'Cuisine'] == '?', :]
# geo_cuisine = geo_cuisine.loc[:, ['Place ID', 'Latitude', 'Longitude', 'Name', 'Alcohol', 'Smoking',
#       'Dress Code', 'Accessibility', 'Price', 'Ambience', 'Area', 'Cuisine'] == '?']
geo_cuisine_loc = geo_cuisine.loc[(geo_cuisine["Place ID"] == '?')&(geo_cuisine["Latitude"] == '?')&(geo_cuisine["Longitude"] == '?')
                              &(geo_cuisine["Name"] == '?')&(geo_cuisine["Alcohol"] == '?')&(geo_cuisine["Smoking"] == '?')
                              &(geo_cuisine["Smoking"] == '?')&(geo_cuisine["Dress Code"] == '?')&(geo_cuisine["Accessibility"] == '?')
                              &(geo_cuisine["Price"] == '?')&(geo_cuisine["Ambience"] == '?')&(geo_cuisine["Area"] == '?')
                              &(geo_cuisine["Cuisine"] == '?')]
geo_cuisine_loc
# Out:
# Empty DataFrame
# Columns: [Place ID, Latitude, Longitude, Name, Alcohol, Smoking, Dress Code, Accessibility, Price, Ambience, Area, Cuisine]
# Index: []

# %%
geo_cuisine
# Out:
#      Place ID   Latitude   Longitude                                Name  \
# 0      135109  18.921785  -99.235350                           Paniroles
# 1      135106  22.149709 -100.976093          El Rinc�n de San Francisco
# 2      135104  23.752982  -99.168434                                vips
# 3      135088  18.876011  -99.219890                   Cafeteria cenidet
# 4      135086  22.141421 -101.013955         Mcdonalds Parque Tangamanga
# ..        ...        ...         ...                                 ...
# 107    132594  23.752168  -99.165709  tacos de barbacoa enfrente del Tec
# 108    132584  23.752365  -99.165288                  Gorditas Dona Tota
# 109    132583  18.922290  -99.234332                    McDonalds Centro
# 110    132572  22.141647 -100.992712                        Cafe Chaires
# 111    132560  23.752304  -99.166913                  puesto de gorditas
#
#                Alcohol        Smoking Dress Code     Accessibility   Price  \
# 0            Wine-Beer  not permitted   informal  no_accessibility  medium
# 1            Wine-Beer    only at bar   informal         partially  medium
# 2             Full_Bar  not permitted   informal        completely  medium
# 3    No_Alcohol_Served  not permitted   informal  no_accessibility     low
# 4    No_Alcohol_Served  not permitted   informal  no_accessibility  medium
# ..                 ...            ...        ...               ...     ...
# 107  No_Alcohol_Served  not permitted   informal        completely     low
# 108  No_Alcohol_Served  not permitted   informal        completely  medium
# 109  No_Alcohol_Served  not permitted   informal         partially     low
# 110  No_Alcohol_Served  not permitted   informal        completely     low
# 111  No_Alcohol_Served      permitted   informal  no_accessibility     low
#
#      Ambience    Area    Cuisine
# 0       quiet  closed    Italian
# 1    familiar    open    Mexican
# 2    familiar  closed    Mexican
# 3       quiet  closed  Cafeteria
# 4    familiar  closed    Burgers
# ..        ...     ...        ...
# 107  familiar    open    Mexican
# 108  familiar  closed    Mexican
# 109  familiar  closed   American
# 110  familiar  closed  Cafeteria
# 111  familiar    open   Regional
#
# [112 rows x 12 columns]

# %%
geo_cuisine.to_csv('./Resources/geocuisine_cleaned.csv', index=False)
