# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# import dependencies
import pandas as pd
import numpy as np

# %%
# Read csv
combo_user = pd.read_csv('FINALCOMBOUSER1.csv')

# Convert csv to data frame
combo_user = pd.DataFrame(combo_user)

combo_user.head()
# Out:
#   user_id   latitude   longitude smoker drink_level dress_perference ambience  \
# 0   U1001  22.139997 -100.978803  false  abstemious         informal   family
# 1   U1001  22.139997 -100.978803  false  abstemious         informal   family
# 2   U1001  22.139997 -100.978803  false  abstemious         informal   family
# 3   U1001  22.139997 -100.978803  false  abstemious         informal   family
# 4   U1001  22.139997 -100.978803  false  abstemious         informal   family
#
#   transport marital_status        hijos  ...  activity  color weight  budget  \
# 0   on foot         single  independent  ...   student  black     69  medium
# 1   on foot         single  independent  ...   student  black     69  medium
# 2   on foot         single  independent  ...   student  black     69  medium
# 3   on foot         single  independent  ...   student  black     69  medium
# 4   on foot         single  independent  ...   student  black     69  medium
#
#   height placeid  rating food_rating  service_rating  rcuisine
# 0   1.77  135051       1           1               2  American
# 1   1.77  135025       2           2               2  American
# 2   1.77  135033       1           1               1  American
# 3   1.77  135045       1           1               1  American
# 4   1.77  135039       1           1               1  American
#
# [5 rows x 24 columns]

# %%
combo_user.columns
# Out:
# Index(['user_id', 'latitude', 'longitude', 'smoker', 'drink_level',
#        'dress_perference', 'ambience', 'transport', 'marital_status', 'hijos',
#        'birth_year', 'interest', 'personality', 'religion', 'activity',
#        'color', 'weight', 'budget', 'height', 'placeid', 'rating',
#        'food_rating', 'service_rating', 'rcuisine'],
#       dtype='object')

# %%
combo_user = combo_user.drop(columns={'color','weight','height','religion','interest','personality' })

# %%
combo_user.head()
# Out:
#   user_id   latitude   longitude smoker drink_level dress_perference ambience  \
# 0   U1001  22.139997 -100.978803  false  abstemious         informal   family
# 1   U1001  22.139997 -100.978803  false  abstemious         informal   family
# 2   U1001  22.139997 -100.978803  false  abstemious         informal   family
# 3   U1001  22.139997 -100.978803  false  abstemious         informal   family
# 4   U1001  22.139997 -100.978803  false  abstemious         informal   family
#
#   transport marital_status        hijos  birth_year activity  budget  placeid  \
# 0   on foot         single  independent        1989  student  medium   135051
# 1   on foot         single  independent        1989  student  medium   135025
# 2   on foot         single  independent        1989  student  medium   135033
# 3   on foot         single  independent        1989  student  medium   135045
# 4   on foot         single  independent        1989  student  medium   135039
#
#    rating  food_rating  service_rating  rcuisine
# 0       1            1               2  American
# 1       2            2               2  American
# 2       1            1               1  American
# 3       1            1               1  American
# 4       1            1               1  American

# %%
combo_user.columns
# Out:
# Index(['user_id', 'latitude', 'longitude', 'smoker', 'drink_level',
#        'dress_perference', 'ambience', 'transport', 'marital_status', 'hijos',
#        'birth_year', 'activity', 'budget', 'placeid', 'rating', 'food_rating',
#        'service_rating', 'rcuisine'],
#       dtype='object')

# %%
combo_user = combo_user.rename(columns={'latitude':'Latitude',
                                        'longitude':'Longitude',
                                        'smoker':'Smoker',
                                        'drink_level':'Alcohol Consumption',
                                       'dress_perference':'Dress Code',
                                       'transport':'Transport',
                                       'marital_status':'Marital Status',
                                       'birth_year':'Birth Year',
                                       'activity':'Occupation',
                                       'budget':'Budget',
                                       'placeid':'Place ID',
                                       'user_id':'User ID',
                                       'rating':'Overall Rating',
                                       'food_rating':'Food Rating',
                                       'service_rating':'Service Rating',
                                       'rcuisine':'Cuisine',
                                       'ambience': 'Ambiance Preference',
                                       'hijos':'Children'})

# %%
combo_user.columns
# Out:
# Index(['User ID', 'Latitude', 'Longitude', 'Smoker', 'Alcohol Consumption',
#        'Dress Code', 'Ambiance Preference', 'Transport', 'Marital Status',
#        'Children', 'Birth Year', 'Occupation', 'Budget', 'Place ID',
#        'Overall Rating', 'Food Rating', 'Service Rating', 'Cuisine'],
#       dtype='object')

# %%
combo_user.head()
# Out:
#   User ID   Latitude   Longitude Smoker Alcohol Consumption Dress Code  \
# 0   U1001  22.139997 -100.978803  false          abstemious   informal
# 1   U1001  22.139997 -100.978803  false          abstemious   informal
# 2   U1001  22.139997 -100.978803  false          abstemious   informal
# 3   U1001  22.139997 -100.978803  false          abstemious   informal
# 4   U1001  22.139997 -100.978803  false          abstemious   informal
#
#   Ambiance Preference Transport Marital Status     Children  Birth Year  \
# 0              family   on foot         single  independent        1989
# 1              family   on foot         single  independent        1989
# 2              family   on foot         single  independent        1989
# 3              family   on foot         single  independent        1989
# 4              family   on foot         single  independent        1989
#
#   Occupation  Budget  Place ID  Overall Rating  Food Rating  Service Rating  \
# 0    student  medium    135051               1            1               2
# 1    student  medium    135025               2            2               2
# 2    student  medium    135033               1            1               1
# 3    student  medium    135045               1            1               1
# 4    student  medium    135039               1            1               1
#
#     Cuisine
# 0  American
# 1  American
# 2  American
# 3  American
# 4  American

# %%
combo_user.nunique()
# Out:
# User ID                138
# Latitude               128
# Longitude              126
# Smoker                   3
# Alcohol Consumption      3
# Dress Code               5
# Ambiance Preference      4
# Transport                4
# Marital Status           4
# Children                 4
# Birth Year              21
# Occupation               5
# Budget                   4
# Place ID               130
# Overall Rating           3
# Food Rating              3
# Service Rating           3
# Cuisine                103
# dtype: int64

# %%
combo_user = combo_user.replace('abstemious','Moderate')

# %%
combo_user_loc = combo_user.loc[(combo_user["User ID"] == '?')&(combo_user["Latitude"] == '?')&(combo_user["Longitude"] == '?')
                                &(combo_user["Smoker"] == '?')&(combo_user["Alcohol Consumption"] == '?')&(combo_user["Dress Code"] == '?')
                                &(combo_user["Ambiance Preference"] == '?')&(combo_user["Transport"] == '?')&(combo_user["Marital Status"] == '?')
                                &(combo_user["Children"] == '?')&(combo_user["Birth Year"] == '?')&(combo_user["Occupation"] == '?')
                                &(combo_user["Budget"] == '?')&(combo_user["Place ID"] == '?')&(combo_user["Overall Rating"] == '?')
                                &(combo_user["Food Rating"] == '?')&(combo_user["Service Rating"] == '?')&(combo_user["Cuisine"] == '?')]
combo_user_loc
# Out:
# Empty DataFrame
# Columns: [User ID, Latitude, Longitude, Smoker, Alcohol Consumption, Dress Code, Ambiance Preference, Transport, Marital Status, Children, Birth Year, Occupation, Budget, Place ID, Overall Rating, Food Rating, Service Rating, Cuisine]
# Index: []

# %%
combo_user = combo_user.loc[(combo_user["User ID"]!= '?')&(combo_user["Latitude"] != '?')&(combo_user["Longitude"] != '?')
                                &(combo_user["Smoker"] != '?')&(combo_user["Alcohol Consumption"] != '?')&(combo_user["Dress Code"] != '?')
                                &(combo_user["Ambiance Preference"] != '?')&(combo_user["Transport"] != '?')&(combo_user["Marital Status"] != '?')
                                &(combo_user["Children"] != '?')&(combo_user["Birth Year"] != '?')&(combo_user["Occupation"] != '?')
                                &(combo_user["Budget"] != '?')&(combo_user["Place ID"] != '?')&(combo_user["Overall Rating"] != '?')
                                &(combo_user["Food Rating"] != '?')&(combo_user["Service Rating"] != '?')&(combo_user["Cuisine"] != '?')]
combo_user
# Out:
#      User ID   Latitude   Longitude Smoker Alcohol Consumption Dress Code  \
# 0      U1001  22.139997 -100.978803  false            Moderate   informal
# 1      U1001  22.139997 -100.978803  false            Moderate   informal
# 2      U1001  22.139997 -100.978803  false            Moderate   informal
# 3      U1001  22.139997 -100.978803  false            Moderate   informal
# 4      U1001  22.139997 -100.978803  false            Moderate   informal
# ...      ...        ...         ...    ...                 ...        ...
# 3414   U1137  22.144803 -100.944623  false      social drinker     formal
# 3415   U1137  22.144803 -100.944623  false      social drinker     formal
# 3416   U1138  22.152884 -100.939663  false      social drinker     formal
# 3417   U1138  22.152884 -100.939663  false      social drinker     formal
# 3418   U1138  22.152884 -100.939663  false      social drinker     formal
#
#      Ambiance Preference Transport Marital Status     Children  Birth Year  \
# 0                 family   on foot         single  independent        1989
# 1                 family   on foot         single  independent        1989
# 2                 family   on foot         single  independent        1989
# 3                 family   on foot         single  independent        1989
# 4                 family   on foot         single  independent        1989
# ...                  ...       ...            ...          ...         ...
# 3414              family    public         single  independent        1989
# 3415              family    public         single  independent        1989
# 3416             friends    public         single  independent        1991
# 3417             friends    public         single  independent        1991
# 3418             friends    public         single  independent        1991
#
#      Occupation  Budget  Place ID  Overall Rating  Food Rating  \
# 0       student  medium    135051               1            1
# 1       student  medium    135025               2            2
# 2       student  medium    135033               1            1
# 3       student  medium    135045               1            1
# 4       student  medium    135039               1            1
# ...         ...     ...       ...             ...          ...
# 3414    student     low    135085               2            1
# 3415    student     low    132951               2            2
# 3416    student  medium    132925               1            2
# 3417    student  medium    132922               2            2
# 3418    student  medium    132921               2            2
#
#       Service Rating   Cuisine
# 0                  2  American
# 1                  2  American
# 2                  1  American
# 3                  1  American
# 4                  1  American
# ...              ...       ...
# 3414               2   Mexican
# 3415               2   Mexican
# 3416               1  Pizzeria
# 3417               2  Pizzeria
# 3418               1  Pizzeria
#
# [3244 rows x 18 columns]

# %%
len(combo_user)
# Out:
# 3244

# %%
combo_user.Occupation.unique()
# Out:
# array(['student', 'professional', 'unemployed', 'working-class'],
#       dtype=object)

# %%
for x in combo_user.columns:
    print(x,combo_user[combo_user[x] == '?'].count() )
# Out:
# User ID User ID                0
# Latitude               0
# Longitude              0
# Smoker                 0
# Alcohol Consumption    0
# Dress Code             0
