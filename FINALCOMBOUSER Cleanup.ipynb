# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect, Column, Integer, String
from sqlalchemy.ext.declarative import declarative_base
# Base = declarative_base()

# %%
# Create Engine
#engine = create_engine(f"sqlite:///{database_path}")
engine = create_engine('postgresql://postgres:password@localhost/IceCream')

# %%
# Declare a Base using 'automap_base()'
Base = automap_base()

# %%
# reflect an existing database into a new model
Base.prepare(engine, reflect=True)

# Print all of the classes mapped to the Base
Base.classes.keys()

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# import dependencies
import pandas as pd
import numpy as np

# %%
# Read csv
combo_user = pd.read_csv('FINALCOMBOUSER1.csv')

# Convert csv to data frame
combo_user = pd.DataFrame(combo_user)

combo_user.head()
# Out:
#   user_id   latitude   longitude  smoker drink_level dress_perference  \
# 0   U1001  22.139997 -100.978803   False  abstemious         informal
# 1   U1001  22.139997 -100.978803   False  abstemious         informal
# 2   U1001  22.139997 -100.978803   False  abstemious         informal
# 3   U1001  22.139997 -100.978803   False  abstemious         informal
# 4   U1001  22.139997 -100.978803   False  abstemious         informal
#
#   ambience transport marital_status        hijos  ...  activity  color weight  \
# 0   family   on foot         single  independent  ...   student  black     69
# 1   family   on foot         single  independent  ...   student  black     69
# 2   family   on foot         single  independent  ...   student  black     69
# 3   family   on foot         single  independent  ...   student  black     69
# 4   family   on foot         single  independent  ...   student  black     69
#
#    budget height placeid  rating food_rating  service_rating  rcuisine
# ...

# %%
combo_user.columns
# Out:
# Index(['user_id', 'latitude', 'longitude', 'smoker', 'drink_level',
#        'dress_perference', 'ambience', 'transport', 'marital_status', 'hijos',
#        'birth_year', 'interest', 'personality', 'religion', 'activity',
#        'color', 'weight', 'budget', 'height', 'placeid', 'rating',
#        'food_rating', 'service_rating', 'rcuisine'],
#       dtype='object')

# %%
combo_user = combo_user.drop(columns={'color','weight','height','religion','interest','personality' })

# %%
combo_user.head()
# Out:
#   user_id   latitude   longitude  smoker drink_level dress_perference  \
# 0   U1001  22.139997 -100.978803   False  abstemious         informal
# 1   U1001  22.139997 -100.978803   False  abstemious         informal
# 2   U1001  22.139997 -100.978803   False  abstemious         informal
# 3   U1001  22.139997 -100.978803   False  abstemious         informal
# 4   U1001  22.139997 -100.978803   False  abstemious         informal
#
#   ambience transport marital_status        hijos  birth_year activity  budget  \
# 0   family   on foot         single  independent        1989  student  medium
# 1   family   on foot         single  independent        1989  student  medium
# 2   family   on foot         single  independent        1989  student  medium
# 3   family   on foot         single  independent        1989  student  medium
# 4   family   on foot         single  independent        1989  student  medium
#
#    placeid  rating  food_rating  service_rating  rcuisine
# ...

# %%
combo_user.columns
# Out:
# Index(['user_id', 'latitude', 'longitude', 'smoker', 'drink_level',
#        'dress_perference', 'ambience', 'transport', 'marital_status', 'hijos',
#        'birth_year', 'activity', 'budget', 'placeid', 'rating', 'food_rating',
#        'service_rating', 'rcuisine'],
#       dtype='object')

# %%
combo_user = combo_user.rename(columns={'latitude':'Latitude',
                                        'longitude':'Longitude',
                                        'smoker':'Smoker',
                                        'drink_level':'Alcohol Consumption',
                                       'dress_perference':'Dress Code',
                                       'transport':'Transport',
                                       'marital_status':'Marital Status',
                                       'birth_year':'Birth Year',
                                       'activity':'Occupation',
                                       'budget':'Budget',
                                       'placeid':'Place ID',
                                       'user_id':'User ID',
                                       'rating':'Overall Rating',
                                       'food_rating':'Food Rating',
                                       'service_rating':'Service Rating',
                                       'rcuisine':'Cuisine',
                                       'ambience': 'Ambiance Preference',
                                       'hijos':'Children'})

# %%
combo_user.columns
# Out:
# Index(['User ID', 'Latitude', 'Longitude', 'Smoker', 'Alcohol Consumption',
#        'Dress Code', 'Ambiance Preference', 'Transport', 'Marital Status',
#        'Children', 'Birth Year', 'Occupation', 'Budget', 'Place ID',
#        'Overall Rating', 'Food Rating', 'Service Rating', 'Cuisine'],
#       dtype='object')

# %%
combo_user.head()
# Out:
#   User ID   Latitude   Longitude  Smoker Alcohol Consumption Dress Code  \
# 0   U1001  22.139997 -100.978803   False          abstemious   informal
# 1   U1001  22.139997 -100.978803   False          abstemious   informal
# 2   U1001  22.139997 -100.978803   False          abstemious   informal
# 3   U1001  22.139997 -100.978803   False          abstemious   informal
# 4   U1001  22.139997 -100.978803   False          abstemious   informal
#
#   Ambiance Preference Transport Marital Status     Children  Birth Year  \
# 0              family   on foot         single  independent        1989
# 1              family   on foot         single  independent        1989
# 2              family   on foot         single  independent        1989
# 3              family   on foot         single  independent        1989
# 4              family   on foot         single  independent        1989
#
#   Occupation  Budget  Place ID  Overall Rating  Food Rating  Service Rating  \
# ...

# %%
combo_user.nunique()
# Out:
# User ID                117
# Latitude               112
# Longitude              110
# Smoker                   2
# Alcohol Consumption      3
# Dress Code               4
# Ambiance Preference      3
# Transport                3
# Marital Status           3
# Children                 3
# Birth Year              20
# Occupation               4
# Budget                   3
# Place ID               130
# Overall Rating           3
# Food Rating              3
# Service Rating           3
# Cuisine                103
# dtype: int64

# %%
combo_user = combo_user.replace('abstemious','Moderate')

# %%
combo_user_loc = combo_user.loc[(combo_user["User ID"] == '?')&(combo_user["Latitude"] == '?')&(combo_user["Longitude"] == '?')
                                &(combo_user["Smoker"] == '?')&(combo_user["Alcohol Consumption"] == '?')&(combo_user["Dress Code"] == '?')
                                &(combo_user["Ambiance Preference"] == '?')&(combo_user["Transport"] == '?')&(combo_user["Marital Status"] == '?')
                                &(combo_user["Children"] == '?')&(combo_user["Birth Year"] == '?')&(combo_user["Occupation"] == '?')
                                &(combo_user["Budget"] == '?')&(combo_user["Place ID"] == '?')&(combo_user["Overall Rating"] == '?')
                                &(combo_user["Food Rating"] == '?')&(combo_user["Service Rating"] == '?')&(combo_user["Cuisine"] == '?')]
combo_user_loc
# Out:
# Empty DataFrame
# Columns: [User ID, Latitude, Longitude, Smoker, Alcohol Consumption, Dress Code, Ambiance Preference, Transport, Marital Status, Children, Birth Year, Occupation, Budget, Place ID, Overall Rating, Food Rating, Service Rating, Cuisine]
# Index: []

# %%
combo_user = combo_user.loc[(combo_user["User ID"]!= '?')|(combo_user["Latitude"] != '?')|(combo_user["Longitude"] != '?')
                                |(combo_user["Smoker"] != '?')|(combo_user["Alcohol Consumption"] != '?')|(combo_user["Dress Code"] != '?')
                                |(combo_user["Ambiance Preference"] != '?')|(combo_user["Transport"] != '?')|(combo_user["Marital Status"] != '?')
                                |(combo_user["Children"] != '?')|(combo_user["Birth Year"] != '?')|(combo_user["Occupation"] != '?')
                                |(combo_user["Budget"] != '?')|(combo_user["Place ID"] != '?')|(combo_user["Overall Rating"] != '?')
                                |(combo_user["Food Rating"] != '?')|(combo_user["Service Rating"] != '?')|(combo_user["Cuisine"] != '?')]
combo_user
# Out:
#      User ID   Latitude   Longitude  Smoker Alcohol Consumption Dress Code  \
# 0      U1001  22.139997 -100.978803   False            Moderate   informal
# 1      U1001  22.139997 -100.978803   False            Moderate   informal
# 2      U1001  22.139997 -100.978803   False            Moderate   informal
# 3      U1001  22.139997 -100.978803   False            Moderate   informal
# 4      U1001  22.139997 -100.978803   False            Moderate   informal
# ...      ...        ...         ...     ...                 ...        ...
# 3239   U1137  22.144803 -100.944623   False      social drinker     formal
# 3240   U1137  22.144803 -100.944623   False      social drinker     formal
# 3241   U1138  22.152884 -100.939663   False      social drinker     formal
# 3242   U1138  22.152884 -100.939663   False      social drinker     formal
# 3243   U1138  22.152884 -100.939663   False      social drinker     formal
#
# ...

# %%
len(combo_user)
# Out:
# 3244

# %%
combo_user.Occupation.unique()
# Out:
# array(['student', 'professional', 'unemployed', 'working-class'],
#       dtype=object)

# %%
for x in combo_user.columns:
    print(x,combo_user[combo_user[x] == '?'].count() )
# Out:
# User ID User ID                0
# Latitude               0
# Longitude              0
# Smoker                 0
# Alcohol Consumption    0
# Dress Code             0
# Ambiance Preference    0
# Transport              0
# Marital Status         0
# Children               0
# Birth Year             0
# Occupation             0
# Budget                 0
# Place ID               0
# Overall Rating         0
# Food Rating            0
# Service Rating         0
# Cuisine                0
# dtype: int64
# Latitude User ID                0
# Latitude               0
# Longitude              0
# Smoker                 0
# Alcohol Consumption    0
# Dress Code             0
# Ambiance Preference    0
# Transport              0
# Marital Status         0
# Children               0
# Birth Year             0
# Occupation             0
# Budget                 0
# Place ID               0
# Overall Rating         0
# Food Rating            0
# Service Rating         0
# ...

# %%
combo_user.to_csv('./Resources/combo_user_cleaneds_v3.csv', index=False)
